# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# FUNCTION:
def convert_to_float(column):
    return [float(i.replace("$","").replace(",","")) for i in column]

# %%
df = pd.read_csv("https://github.com/ynfresfin/stock_data/raw/main/V_HistoricalData_1726077072765.csv",
                 parse_dates=["Date"],
                 index_col=['Date'])

df["Close/Last"] = convert_to_float(df["Close/Last"])
df["Open"] = convert_to_float(df["Open"])

# %%
print(df)
# Out:
#             Close/Last    Volume     Open       High      Low
# Date
# 2024-09-10      285.34   5314413  $285.93  $286.3981  $283.57
# 2024-09-09      285.61  10933860  $282.09    $286.97  $281.65
# 2024-09-06      279.37   7187805  $277.77    $280.28  $277.43
# 2024-09-05      278.62   6447539  $281.00    $281.50  $277.41
# 2024-09-04      280.49   6107450  $278.71   $281.645  $278.70
# ...                ...       ...      ...        ...      ...
# 2019-09-17      176.45   5940308  $176.83    $178.26  $175.04
# 2019-09-16      176.11   4253607  $176.17    $177.20  $175.51
# 2019-09-13      177.27   6103245  $178.65    $178.77  $176.02
# 2019-09-12      177.98   7748794  $176.85    $179.41  $176.68
# 2019-09-11      174.98   9113604  $177.40   $177.925  $174.45
#
# [1258 rows x 5 columns]

# %%
df.index.min()
# Out:
# Timestamp('2019-09-11 00:00:00')

# %%
df.index.max()
# Out:
# Timestamp('2024-09-10 00:00:00')

# %%
df["Close/Last"].describe()
# Out:
# count    1258.000000
# mean      220.285429
# std        29.080652
# min       135.740000
# 25%       200.297500
# 50%       216.625000
# 75%       235.137500
# max       290.370000
# Name: Close/Last, dtype: float64

# %%
df["Close/Last"].plot()
df["Open"].plot()
# Out:
# <Axes: xlabel='Date'>
